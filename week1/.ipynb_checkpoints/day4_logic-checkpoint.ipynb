# %%
print("Начинаю 4-й день обучения!")
# Out:
# Начинаю 4-й день обучения!

# %%
age = 22
print("Ваш возраст:", age)
# Out:
# Ваш возраст: 22

# %%
age = 22
if age >= 18:
    print("Доступ разрешен")
else:
    print("Доступ запрещен")
# Out:
# Доступ разрешен

# %%
 temperature = 5
if temperature < 0:
    print("очень холодно")
elif temperature < 10: 
    print("прохладно")
else:
    print("тепло")
# Out:
# прохладно

# %%
for i in range(1,6):
 print("шаг номер",i)
# Out:
# шаг номер 1
# шаг номер 2
# шаг номер 3
# шаг номер 4
# шаг номер 5
