# %%
# День 5: списки и функции

numbers = [3, 7, 12, 5, 9]
numbers

# %%
numbers[0]      # первый элемент
numbers[-1]     # последний элемент
numbers[1:4]    # срез: элементы с 1 по 3

# %%
number.append(20)
numbers

# %%
def mean_value(values):
    total = 0 
    for v in values 
    total += v
    return total / len(values)
    mean_value([10,20,30,40])

# %%
 Список значений загрязнения по точкам
pollution = [12, 18, 31, 22, 15, 40, 27]
# Найти:
# 1) минимальное значение
# 2) максимальное значение
# 3) среднее значение (с помощью функции)
# 4) вывести все значения > 20
print("Минимум", min(pollution))
print("Максимум", max(pollution))
print("Среднее", mean_value(pollution))
print("Значение выше 20:")
for p in pollution:
    if p > 20: 
        print(p)
