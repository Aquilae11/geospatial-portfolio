# %%
# День 4: основы логики Python
print("Начинаю 4-й день обучения!")

# %%
age = 22
print("Ваш возраст:", age)

# %%
age = 22
if age >= 18:
    print("Доступ разрешен")
Else:
    print("Доступ запрещен")

# %%
 temperature = 5
if temperature < 0:
    print("очень холодно")
elif temperture < 10: 
    print("прохладно")
else 
print("тепло")

# %%
for i in range(1,6):
 print("шаг номер"i)
