# %%
print("Somthing new here")
# Out:
# Somthing new here

# %%
A=10 b=15 a+b
# Out:
#   Cell In[2], line 1
#     A=10 b=15 a+b
#          ^
# SyntaxError: invalid syntax

# %%
a=10

# %%
b=15

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a+b
#
# NameError: name 'a' is not defined

# %%
a = 10
b = 15
a + b
# Out:
# 25

# %%
def square(x):
    return x * x
    square(7)
